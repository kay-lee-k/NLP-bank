# %% [markdown]
# <a href="https://colab.research.google.com/github/kay-lee-k/NLP-bank/blob/main/%5BNLP%5Ddata_crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# batch화를 통한 크롤링 개선

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.5 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import reviews

print("✅ google_play_scraper 정상적으로 불러옴!")
# Out:
# ✅ google_play_scraper 정상적으로 불러옴!

# %%
from google_play_scraper import reviews, Sort
import pandas as pd
import time

app_id = "com.ibk.android.ionebank"
lang = "ko"
country = "kr"

all_reviews = []
batch_size = 1000  # 한 번에 가져올 리뷰 개수
total_reviews = 370000  # 목표 개수
page = 1

while len(all_reviews) < total_reviews:
    result, _ = reviews(
        app_id,
        lang=lang,
        country=country,
        count=batch_size,
        sort=Sort.NEWEST,  # 최신순 정렬
    )
    all_reviews.extend(result)
    print(f"✅ {len(all_reviews)}건 수집 완료")
    time.sleep(2)  # API 요청 간격 조정

df = pd.DataFrame(all_reviews)
df.to_csv("google_play_reviews.csv", index=False, encoding="utf-8")
print("🎉 데이터 저장 완료!")
# Out:
# ✅ 1000건 수집 완료
# ✅ 2000건 수집 완료
# ✅ 3000건 수집 완료
# ✅ 4000건 수집 완료
# ✅ 5000건 수집 완료
# ✅ 6000건 수집 완료
# ✅ 7000건 수집 완료
# ✅ 8000건 수집 완료
# ✅ 9000건 수집 완료
# ✅ 10000건 수집 완료
# ✅ 11000건 수집 완료
# ✅ 12000건 수집 완료
# ✅ 13000건 수집 완료
# ✅ 14000건 수집 완료
# ✅ 15000건 수집 완료
# ✅ 16000건 수집 완료
# ✅ 17000건 수집 완료
# ✅ 18000건 수집 완료
# ✅ 19000건 수집 완료
# ✅ 20000건 수집 완료
# ✅ 21000건 수집 완료
# ✅ 22000건 수집 완료
# ✅ 23000건 수집 완료
# ✅ 24000건 수집 완료
# ✅ 25000건 수집 완료
# ✅ 26000건 수집 완료
# ✅ 27000건 수집 완료
# ✅ 28000건 수집 완료
# ✅ 29000건 수집 완료
# ✅ 30000건 수집 완료
# ✅ 31000건 수집 완료
# ✅ 32000건 수집 완료
# ✅ 33000건 수집 완료
# ✅ 34000건 수집 완료
# ✅ 35000건 수집 완료
# ✅ 36000건 수집 완료
# ✅ 37000건 수집 완료
# ✅ 38000건 수집 완료
# ✅ 39000건 수집 완료
# ✅ 40000건 수집 완료
# ✅ 41000건 수집 완료
# ✅ 42000건 수집 완료
# ✅ 43000건 수집 완료
# ✅ 44000건 수집 완료
# ✅ 45000건 수집 완료
# ✅ 46000건 수집 완료
# ✅ 47000건 수집 완료
# ✅ 48000건 수집 완료
# ✅ 49000건 수집 완료
# ✅ 50000건 수집 완료
# ✅ 51000건 수집 완료
# ✅ 52000건 수집 완료
# ✅ 53000건 수집 완료
# ✅ 54000건 수집 완료
# ✅ 55000건 수집 완료
# ✅ 56000건 수집 완료
# ✅ 57000건 수집 완료
# ✅ 58000건 수집 완료
# ✅ 59000건 수집 완료
# ✅ 60000건 수집 완료
# ✅ 61000건 수집 완료
# ✅ 62000건 수집 완료
# ✅ 63000건 수집 완료
# ✅ 64000건 수집 완료
# ✅ 65000건 수집 완료
# ✅ 66000건 수집 완료
# ✅ 67000건 수집 완료
# ✅ 68000건 수집 완료
# ✅ 69000건 수집 완료
# ✅ 70000건 수집 완료
# ✅ 71000건 수집 완료
# ✅ 72000건 수집 완료
# ✅ 73000건 수집 완료
# ✅ 74000건 수집 완료
# ✅ 75000건 수집 완료
# ✅ 76000건 수집 완료
# ✅ 77000건 수집 완료
# ✅ 78000건 수집 완료
# ✅ 79000건 수집 완료
# ✅ 80000건 수집 완료
# ✅ 81000건 수집 완료
# ✅ 82000건 수집 완료
# ✅ 83000건 수집 완료
# ✅ 84000건 수집 완료
# ✅ 85000건 수집 완료
# ✅ 86000건 수집 완료
# ✅ 87000건 수집 완료
# ✅ 88000건 수집 완료
# ✅ 89000건 수집 완료
# ✅ 90000건 수집 완료
# ✅ 91000건 수집 완료
# ✅ 92000건 수집 완료
# ✅ 93000건 수집 완료
# ✅ 94000건 수집 완료
# ✅ 95000건 수집 완료
# ✅ 96000건 수집 완료
# ✅ 97000건 수집 완료
# ✅ 98000건 수집 완료
# ✅ 99000건 수집 완료
# ✅ 100000건 수집 완료
# ✅ 101000건 수집 완료
# ✅ 102000건 수집 완료
# ✅ 103000건 수집 완료
# ✅ 104000건 수집 완료
# ✅ 105000건 수집 완료
# ✅ 106000건 수집 완료
# ✅ 107000건 수집 완료
# ✅ 108000건 수집 완료
# ✅ 109000건 수집 완료
# ✅ 110000건 수집 완료
# ✅ 111000건 수집 완료
# ✅ 112000건 수집 완료
# ✅ 113000건 수집 완료
# ✅ 114000건 수집 완료
# ✅ 115000건 수집 완료
# ✅ 116000건 수집 완료
# ✅ 117000건 수집 완료
# ✅ 118000건 수집 완료
# ✅ 119000건 수집 완료
# ✅ 120000건 수집 완료
# ✅ 121000건 수집 완료
# ✅ 122000건 수집 완료
# ✅ 123000건 수집 완료
# ✅ 124000건 수집 완료
# ✅ 125000건 수집 완료
# ✅ 126000건 수집 완료
# ✅ 127000건 수집 완료
# ✅ 128000건 수집 완료
# ✅ 129000건 수집 완료
# ✅ 130000건 수집 완료
# ✅ 131000건 수집 완료
# ✅ 132000건 수집 완료
# ✅ 133000건 수집 완료
# ✅ 134000건 수집 완료
# ✅ 135000건 수집 완료
# ✅ 136000건 수집 완료
# ✅ 137000건 수집 완료
# ✅ 138000건 수집 완료
# ✅ 139000건 수집 완료
# ✅ 140000건 수집 완료
# ✅ 141000건 수집 완료
# ✅ 142000건 수집 완료
# ✅ 143000건 수집 완료
# ✅ 144000건 수집 완료
# ✅ 145000건 수집 완료
# ✅ 146000건 수집 완료
# ✅ 147000건 수집 완료
# ✅ 148000건 수집 완료
# ✅ 149000건 수집 완료
# ✅ 150000건 수집 완료
# ✅ 151000건 수집 완료
# ✅ 152000건 수집 완료
# ✅ 153000건 수집 완료
# ✅ 154000건 수집 완료
# ✅ 155000건 수집 완료
# ✅ 156000건 수집 완료
# ✅ 157000건 수집 완료
# ✅ 158000건 수집 완료
# ✅ 159000건 수집 완료
# ✅ 160000건 수집 완료
# ✅ 161000건 수집 완료
# ✅ 162000건 수집 완료
# ✅ 163000건 수집 완료
# ✅ 164000건 수집 완료
# ✅ 165000건 수집 완료
# ✅ 166000건 수집 완료
# ✅ 167000건 수집 완료
# ✅ 168000건 수집 완료
# ✅ 169000건 수집 완료
# ✅ 170000건 수집 완료
# ✅ 171000건 수집 완료
# ✅ 172000건 수집 완료
# ✅ 173000건 수집 완료
# ✅ 174000건 수집 완료
# ✅ 175000건 수집 완료
# ✅ 176000건 수집 완료
# ✅ 177000건 수집 완료
# ✅ 178000건 수집 완료
# ✅ 179000건 수집 완료
# ✅ 180000건 수집 완료
# ✅ 181000건 수집 완료
# ✅ 182000건 수집 완료
# ✅ 183000건 수집 완료
# ✅ 184000건 수집 완료
# ✅ 185000건 수집 완료
# ✅ 186000건 수집 완료
# ✅ 187000건 수집 완료
# ✅ 188000건 수집 완료
# ✅ 189000건 수집 완료
# ✅ 190000건 수집 완료
# ✅ 191000건 수집 완료
# ✅ 192000건 수집 완료
# ✅ 193000건 수집 완료
# ✅ 194000건 수집 완료
# ✅ 195000건 수집 완료
# ✅ 196000건 수집 완료
# ✅ 197000건 수집 완료
# ✅ 198000건 수집 완료
# ✅ 199000건 수집 완료
# ✅ 200000건 수집 완료
# ✅ 201000건 수집 완료
# ✅ 202000건 수집 완료
# ✅ 203000건 수집 완료
# ✅ 204000건 수집 완료
# ✅ 205000건 수집 완료
# ✅ 206000건 수집 완료
# ✅ 207000건 수집 완료
# ✅ 208000건 수집 완료
# ✅ 209000건 수집 완료
# ✅ 210000건 수집 완료
# ✅ 211000건 수집 완료
# ✅ 212000건 수집 완료
# ✅ 213000건 수집 완료
# ✅ 214000건 수집 완료
# ✅ 215000건 수집 완료
# ✅ 216000건 수집 완료
# ✅ 217000건 수집 완료
# ✅ 218000건 수집 완료
# ✅ 219000건 수집 완료
# ✅ 220000건 수집 완료
# ✅ 221000건 수집 완료
# ✅ 222000건 수집 완료
# ✅ 223000건 수집 완료
# ✅ 224000건 수집 완료
# ✅ 225000건 수집 완료
# ✅ 226000건 수집 완료
# ✅ 227000건 수집 완료
# ✅ 228000건 수집 완료
# ✅ 229000건 수집 완료
# ✅ 230000건 수집 완료
# ✅ 231000건 수집 완료
# ✅ 232000건 수집 완료
# ✅ 233000건 수집 완료
# ✅ 234000건 수집 완료
# ✅ 235000건 수집 완료
# ✅ 236000건 수집 완료
# ✅ 237000건 수집 완료
# ✅ 238000건 수집 완료
# ✅ 239000건 수집 완료
# ✅ 240000건 수집 완료
# ✅ 241000건 수집 완료
# ✅ 242000건 수집 완료
# ✅ 243000건 수집 완료
# ✅ 244000건 수집 완료
# ✅ 245000건 수집 완료
# ✅ 246000건 수집 완료
# ✅ 247000건 수집 완료
# ✅ 248000건 수집 완료
# ✅ 249000건 수집 완료
# ✅ 250000건 수집 완료
# ✅ 251000건 수집 완료
# ✅ 252000건 수집 완료
# ✅ 253000건 수집 완료
# ✅ 254000건 수집 완료
# ✅ 255000건 수집 완료
# ✅ 256000건 수집 완료
# ✅ 257000건 수집 완료
# ✅ 258000건 수집 완료
# ✅ 259000건 수집 완료
# ✅ 260000건 수집 완료
# ✅ 261000건 수집 완료
# ✅ 262000건 수집 완료
# ✅ 263000건 수집 완료
# ✅ 264000건 수집 완료
# ✅ 265000건 수집 완료
# ✅ 266000건 수집 완료
# ✅ 267000건 수집 완료
# ✅ 268000건 수집 완료
# ✅ 269000건 수집 완료
# ✅ 270000건 수집 완료
# ✅ 271000건 수집 완료
# ✅ 272000건 수집 완료
# ✅ 273000건 수집 완료
# ✅ 274000건 수집 완료
# ✅ 275000건 수집 완료
# ✅ 276000건 수집 완료
# ✅ 277000건 수집 완료
# ✅ 278000건 수집 완료
# ✅ 279000건 수집 완료
# ✅ 280000건 수집 완료
# ✅ 281000건 수집 완료
# ✅ 282000건 수집 완료
# ✅ 283000건 수집 완료
# ✅ 284000건 수집 완료
# ✅ 285000건 수집 완료
# ✅ 286000건 수집 완료
# ✅ 287000건 수집 완료
# ✅ 288000건 수집 완료
# ✅ 289000건 수집 완료
# ✅ 290000건 수집 완료
# ✅ 291000건 수집 완료
# ✅ 292000건 수집 완료
# ✅ 293000건 수집 완료
# ✅ 294000건 수집 완료
# ✅ 295000건 수집 완료
# ✅ 296000건 수집 완료
# ✅ 297000건 수집 완료
# ✅ 298000건 수집 완료
# ✅ 299000건 수집 완료
# ✅ 300000건 수집 완료
# ✅ 301000건 수집 완료
# ✅ 302000건 수집 완료
# ✅ 303000건 수집 완료
# ✅ 304000건 수집 완료
# ✅ 305000건 수집 완료
# ✅ 306000건 수집 완료
# ✅ 307000건 수집 완료
# ✅ 308000건 수집 완료
# ✅ 309000건 수집 완료
# ✅ 310000건 수집 완료
# ✅ 311000건 수집 완료
# ✅ 312000건 수집 완료
# ✅ 313000건 수집 완료
# ✅ 314000건 수집 완료
# ✅ 315000건 수집 완료
# ✅ 316000건 수집 완료
# ✅ 317000건 수집 완료
# ✅ 318000건 수집 완료
# ✅ 319000건 수집 완료
# ✅ 320000건 수집 완료
# ✅ 321000건 수집 완료
# ✅ 322000건 수집 완료
# ✅ 323000건 수집 완료
# ✅ 324000건 수집 완료
# ✅ 325000건 수집 완료
# ✅ 326000건 수집 완료
# ✅ 327000건 수집 완료
# ✅ 328000건 수집 완료
# ✅ 329000건 수집 완료
# ✅ 330000건 수집 완료
# ✅ 331000건 수집 완료
# ✅ 332000건 수집 완료
# ✅ 333000건 수집 완료
# ✅ 334000건 수집 완료
# ✅ 335000건 수집 완료
# ✅ 336000건 수집 완료
# ✅ 337000건 수집 완료
# ✅ 338000건 수집 완료
# ✅ 339000건 수집 완료
# ✅ 340000건 수집 완료
# ✅ 341000건 수집 완료
# ✅ 342000건 수집 완료
# ✅ 343000건 수집 완료
# ✅ 344000건 수집 완료
# ✅ 345000건 수집 완료
# ✅ 346000건 수집 완료
# ✅ 347000건 수집 완료
# ✅ 348000건 수집 완료
# ✅ 349000건 수집 완료
# ✅ 350000건 수집 완료
# ✅ 351000건 수집 완료
# ✅ 352000건 수집 완료
# ✅ 353000건 수집 완료
# ✅ 354000건 수집 완료
# ✅ 355000건 수집 완료
# ✅ 356000건 수집 완료
# ✅ 357000건 수집 완료
# ✅ 358000건 수집 완료
# ✅ 359000건 수집 완료
# ✅ 360000건 수집 완료
# ✅ 361000건 수집 완료
# ✅ 362000건 수집 완료
# ✅ 363000건 수집 완료
# ✅ 364000건 수집 완료
# ✅ 365000건 수집 완료
# ✅ 366000건 수집 완료
# ✅ 367000건 수집 완료
# ✅ 368000건 수집 완료
# ✅ 369000건 수집 완료
# ✅ 370000건 수집 완료
# 🎉 데이터 저장 완료!

# %%
import os
print(os.listdir())  # 현재 디렉토리에 저장된 파일 목록 확인
# Out:
# ['.config', 'google_play_reviews.csv', 'sample_data']

# %%
from google.colab import files
files.download("google_play_reviews.csv")  # 파일 다운로드
